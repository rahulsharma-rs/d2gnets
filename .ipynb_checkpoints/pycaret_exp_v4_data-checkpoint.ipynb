# %%
#!pip install --pre pycaret

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
from sklearn.preprocessing import QuantileTransformer, quantile_transform

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,  r2_score

# %%
from pycaret.regression import *
from pycaret.utils import check_metric

# %%
IC50_transformer = load_model('/data/user/rsharma3/nbotw/Project-D2GNETs/models/LNIC50_Model/Final_et_LNIC50_Model_25June2022')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
panCancer_train_df = pd.read_csv('/data/user/rsharma3/nbotw/Project-D2GNETs/data/panCancer_train_CGC_657_new_drug_features_v4_df.csv')
GBM_train_df = pd.read_csv('/data/user/rsharma3/nbotw/Project-D2GNETs/data/GBM_train_CGC_657_new_drug_features_v4_df.csv')
#GBM_test_df = pd.read_csv('/data/user/rsharma3/nbotw/Project-D2GNETs/data/GBM_test_CGC_657_new_drug_features_v2_df.csv')
GBM_DRUG_LIST = ['Carmustine','Temozolomide']
TARGET = 'LN_IC50'
Un_Imp_Features = ['DATASET', 'NLME_RESULT_ID', 'NLME_CURVE_ID', 'COSMIC_ID',
       'CELL_LINE_NAME', 'SANGER_MODEL_ID', 'TCGA_DESC', 'DRUG_ID',
       'DRUG_NAME', 'PUTATIVE_TARGET', 'PATHWAY_NAME', 'COMPANY_ID',
       'WEBRELEASE', 'MIN_CONC', 'MAX_CONC', 'AUC', 'RMSE',
       'Z_SCORE', 'index', 'PUBCHEM_ID', 'SMILES', 'WORDS', 'SAMPLE_ID','WordMap','index']
#X_cols =panCancer_train_df.columns[25:].to_list() #list(set(GBM_test_df.columns)-set(Un_Imp_Features))
#Y_col = TARGET
#features = list(set(GBM_test_df.columns)-set(TARGET))

# %%
#panCancer_train_df=None
#GBM_train_df =None
#GBM_test_df = None

# %%
featureScore = pd.read_csv('/data/user/rsharma3/nbotw/Project-D2GNETs/Supplementary_Material/featureScore_v4.csv')
featureScore = featureScore[featureScore['Score']>=70]
features = set(featureScore['Name'].to_list())

# %%
len(features)
# Out:
# 2473

# %%
disease_cols = (pd.read_csv('/data/user/rsharma3/nbotw/Project-D2GNETs/data/diseaseNames.csv')).columns.tolist()
GE_cols =  (pd.read_csv('/data/user/rsharma3/nbotw/Project-D2GNETs/data/657_Gene_name.csv')).columns.tolist()
drug_cols =  (pd.read_csv('/data/user/rsharma3/nbotw/Project-D2GNETs/data/moleculeNames.csv')).columns.tolist()

# %%
#list(features.intersection(set(panCancer_train_df.columns[55+2986:].to_list())))

Drug_Xcols = list(features.intersection(set(drug_cols)))+disease_cols
GE_Xcols = GE_cols#list(features.intersection(set(panCancer_train_df.columns[55+2986:].to_list())))

# %%
print(f"No. of Diseases: {len(disease_cols)}")
print(f"No. of Drugs Features: {len(Drug_Xcols)}")
print(f"No. of GENEs: {len(GE_Xcols)}")
# Out:
# No. of Diseases: 31
# No. of Drugs Features: 1999
# No. of GENEs: 657

# %%
GBM_test_Carmustine = GBM_train_df[GBM_train_df['DRUG_NAME']=='Carmustine'].copy(deep=True)
#GBM_test_Docetaxel = GBM_test_df[GBM_test_df['DRUG_NAME']=='Docetaxel'].copy(deep=True)
#GBM_test_Crizotinib = GBM_test_df[GBM_test_df['DRUG_NAME']=='Crizotinib'].copy(deep=True)
GBM_test_Temozolomide = GBM_train_df[GBM_train_df['DRUG_NAME']=='Temozolomide'].copy(deep=True)

# %%
indx_4_drugs = (GBM_test_Carmustine.index.to_list()+
 GBM_test_Temozolomide.index.to_list())
GBM_train_df.drop(index=indx_4_drugs,inplace=True)

# %%
24+25+96219+22838
# Out:
# 119106

# %%
panCancer_df = pd.concat([panCancer_train_df,GBM_train_df],axis=0)
panCancer_df = panCancer_df[Drug_Xcols+GE_Xcols+['TCGA_DESC','LN_IC50','SAMPLE_ID','DRUG_NAME']]
panCancer_df.dropna(inplace=True)
#panCancer_df = panCancer_df[panCancer_df['TCGA_DESC']!='UNCLASSIFIED']
#PC_DF = preprocessing.MinMaxScaler().fit_transform(panCancer_df[Drug_Xcols+GE_Xcols])
#PC_DF = pd.DataFrame(PC_DF,columns=Drug_Xcols+GE_Xcols)
#panCancer_df = pd.concat([panCancer_df[['TCGA_DESC','LN_IC50']].reset_index(),PC_DF], axis=1)

#panCancer_df.drop(columns=['index'],inplace=True)

# %%
train = panCancer_df.sample(frac=0.8).copy(deep=True)#.values
test = panCancer_df.drop(index=train.index).copy(deep=True)
#test = temp.sample(frac=0.7).copy(deep=True)
#train = pd.concat([train,test],axis=0)
#test_unseen = temp.drop(index=test.index).copy(deep=True)
#X_GE = panCancer_df[GE_Xcols]#.values

# %%
print(f"Train data size: {train.shape[0]}")
print(f"Test data size: {test.shape[0]}")
# Out:
# Train data size: 96219
# Test data size: 22809

# %%
qt1 = QuantileTransformer(n_quantiles=2, random_state=42,output_distribution='uniform')
#qt2 = QuantileTransformer(n_quantiles=200, random_state=0)

train['LN_IC50_t'] = qt1.fit_transform(
    train['LN_IC50'].values.reshape(-1, 1))
test['LN_IC50_t'] = qt1.fit_transform(
    test['LN_IC50'].values.reshape(-1, 1))

#test_unseen['LN_IC50_t'] = qt1.fit_transform(test_unseen['LN_IC50'].values.reshape(-1, 1))

GBM_test_Carmustine['LN_IC50_t'] = qt1.fit_transform(GBM_test_Carmustine['LN_IC50'].values.reshape(-1, 1))
GBM_test_Temozolomide['LN_IC50_t'] = qt1.fit_transform(GBM_test_Temozolomide['LN_IC50'].values.reshape(-1, 1))

# %%
from pycaret.regression import *

# %%
exp1 = setup(data=train[['LN_IC50_t','LN_IC50']], target='LN_IC50', test_data=test[['LN_IC50_t','LN_IC50']],numeric_features=['LN_IC50_t']
           ,transformation = False, normalize=False,use_gpu=True,polynomial_features=True,polynomial_degree=3)

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_4c220_ th {
#   text-align: left;
# }
# ...

# %%
et_LNIC50 = create_model('et')
# Out:
# <style type="text/css">
# #T_806f2_row10_col0, #T_806f2_row10_col1, #T_806f2_row10_col2, #T_806f2_row10_col3, #T_806f2_row10_col4, #T_806f2_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_806f2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_806f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_806f2_row0_col0" class="data row0 col0" >0.0001</td>
#       <td id="T_806f2_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_806f2_row0_col2" class="data row0 col2" >0.0038</td>
# ...

# %%
et_res= pull()

# %%
et_res.to_csv('/data/user/rsharma3/nbotw/Project-D2GNETs/result/LabelModel10fold.csv')

# %%
predict_model(et_LNIC50);
# Out:
# <style type="text/css">
# </style>
# <table id="T_15b00_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15b00_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_15b00_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_15b00_row0_col1" class="data row0 col1" >0.2851</td>
#       <td id="T_15b00_row0_col2" class="data row0 col2" >0.0955</td>
#       <td id="T_15b00_row0_col3" class="data row0 col3" >0.3090</td>
# ...

# %%
final_et_LNIC50 = finalize_model(et_LNIC50)

# %%
save_model(final_et_LNIC50,'/data/user/rsharma3/nbotw/Project-D2GNETs/models/LNIC50_Model/Final_et_LNIC50_Model_25June2022')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=['LN_IC50_t'],
#                                        target='LN_IC50', time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numer...
#                   ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0,
#                                       criterion='mse', max_depth=None,
#                                       max_features='auto', max_leaf_nodes=None,
# ...

# %%
exp = setup(data=train, target='LN_IC50_t', test_data=test,  ignore_features=['TCGA_DESC','LN_IC50','SAMPLE_ID','DRUG_NAME'],numeric_features=disease_cols+Drug_Xcols+GE_Xcols
           ,transformation = False, normalize=False,use_gpu=True)
# Out:
# <style type="text/css">
# #T_62441_row16_col1, #T_62441_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_62441_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62441_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_62441_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_62441_row0_col1" class="data row0 col1" >6778</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_62441_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_62441_row1_col1" class="data row1 col1" >LN_IC50_t</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
models()
# Out:
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
#                                        Name  \
# ID
# lr                        Linear Regression
# lasso                      Lasso Regression
# ridge                      Ridge Regression
# en                              Elastic Net
# lar                  Least Angle Regression
# llar           Lasso Least Angle Regression
# omp             Orthogonal Matching Pursuit
# br                           Bayesian Ridge
# ard       Automatic Relevance Determination
# par            Passive Aggressive Regressor
# ransac              Random Sample Consensus
# tr                       TheilSen Regressor
# huber                       Huber Regressor
# kr                             Kernel Ridge
# svm               Support Vector Regression
# knn                   K Neighbors Regressor
# dt                  Decision Tree Regressor
# rf                  Random Forest Regressor
# ...

# %%
mdl1= compare_models(include=['lr','knn','gbr','dt','ridge','ada','lasso','rf','lightgbm','et'])
# Out:
# <style type="text/css">
# #T_991fb_ th {
#   text-align: left;
# }
# ...

# %%
mdl1_1 = pull()
mdl1_1.to_csv('/data/user/rsharma3/nbotw/Project-D2GNETs/result/modelSelection.csv')

# %%
lr = create_model('lr')
# Out:
# <style type="text/css">
# #T_36758_row10_col0, #T_36758_row10_col1, #T_36758_row10_col2, #T_36758_row10_col3, #T_36758_row10_col4, #T_36758_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_36758_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36758_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_36758_row0_col0" class="data row0 col0" >0.0502</td>
#       <td id="T_36758_row0_col1" class="data row0 col1" >0.0045</td>
#       <td id="T_36758_row0_col2" class="data row0 col2" >0.0671</td>
# ...

# %%
lgbm = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_bc5f3_row10_col0, #T_bc5f3_row10_col1, #T_bc5f3_row10_col2, #T_bc5f3_row10_col3, #T_bc5f3_row10_col4, #T_bc5f3_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_bc5f3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc5f3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bc5f3_row0_col0" class="data row0 col0" >0.0474</td>
#       <td id="T_bc5f3_row0_col1" class="data row0 col1" >0.0040</td>
#       <td id="T_bc5f3_row0_col2" class="data row0 col2" >0.0634</td>
# ...

# %%
x=pd.DataFrame({'Feature': get_config('X_train').columns}).to_csv('/data/user/rsharma3/nbotw/Project-D2GNETs/result/feature.csv')

# %%
657+618+31
# Out:
# 1306

# %%
get_config('X_train').columns[850:1000]
# Out:
# Index(['TFG', 'BRD3', 'ROS1', 'MLLT10', 'SH3GL1', 'SPEN', 'ERCC3', 'JAK2',
#        'DDX6', 'PDE4DIP',
#        ...
#        'FLT3', 'ALK', 'SETD2', 'WT1', 'ERC1', 'VAV1', 'NF2', 'XPC', 'FAM131B',
#        'LEF1'],
#       dtype='object', length=150)

# %%
lgbm_res= pull()

# %%
lgbm_res.to_csv('/data/user/rsharma3/nbotw/Project-D2GNETs/result/LGBM10fold.csv')

# %%
final_lgbm = finalize_model(lgbm)
save_model(final_et_LNIC50,'/data/user/rsharma3/nbotw/Project-D2GNETs/models/LGBM/Final_lgbm_Model_25June2022')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True,
#                                        features_todrop=['TCGA_DESC', 'LN_IC50',
#                                                         'SAMPLE_ID',
#                                                         'DRUG_NAME'],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=['ACC', 'ALL', 'BLCA',
#                                                            'BRCA', 'CESC', 'CLL',
#                                                            'COREAD', 'DLBC',
#                                                            'ESCA', 'GBM', 'HNSC',
#                                                            'KIRC', 'LAML',
# ...

# %%
unseen_predict =predict_model(lgbm, data=test)

# %%
predict_model(lgbm)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c97d0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c97d0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c97d0_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_c97d0_row0_col1" class="data row0 col1" >0.0510</td>
#       <td id="T_c97d0_row0_col2" class="data row0 col2" >0.0047</td>
#       <td id="T_c97d0_row0_col3" class="data row0 col3" >0.0682</td>
# ...

# %%
GBM_Carmustine_pred = predict_model(final_lgbm, data=GBM_test_Carmustine)
GBM_Temozolomide_pred = predict_model(final_lgbm, data=GBM_test_Temozolomide)

# %%
unseen_predict.to_csv('/data/user/rsharma3/nbotw/Project-D2GNETs/result/unseen_predict.csv',index=False)
#predict_train.to_csv('/data/user/rsharma3/nbotw/Project-D2GNETs/result/predict_train.csv',index=False)
GBM_Carmustine_pred.to_csv('/data/user/rsharma3/nbotw/Project-D2GNETs/result/GBM_Carmustine_pred.csv',index=False)
GBM_Temozolomide_pred.to_csv('/data/user/rsharma3/nbotw/Project-D2GNETs/result/GBM_Temozolomide_pred.csv',index=False)

# %%
get_metrics()
# Out:
#         Name Display Name                                     Score Function  \
# ID
# mae      MAE          MAE   <function mean_absolute_error at 0x2aab61b17c20>
# mse      MSE          MSE    <function mean_squared_error at 0x2aab61b17f80>
# rmse    RMSE         RMSE    <function mean_squared_error at 0x2aab61b17f80>
# r2        R2           R2              <function r2_score at 0x2aab61b1f320>
# rmsle  RMSLE        RMSLE  <function RMSLEMetricContainer.__init__.<local...
# mape    MAPE         MAPE  <function MAPEMetricContainer.__init__.<locals...
#
#                                                   Scorer Target  \
# ID
# mae                              neg_mean_absolute_error   pred
# mse                               neg_mean_squared_error   pred
# rmse                         neg_root_mean_squared_error   pred
# r2                                                    r2   pred
# rmsle  make_scorer(root_mean_squared_log_error, great...   pred
# ...

# %%
from pycaret.utils import check_metric

# %%
metrics_func(unseen_predict.LN_IC50_t, unseen_predict.Label)
# Out:
# [0.051, 0.0047, 0.0682, 0.8034, 0.0456, 0.1222]

# %%
def metrics_func(true_label,prediction):
    lst = []
    lst.append(check_metric(true_label, prediction,'MAE',))
    lst.append(check_metric(true_label, prediction,'MSE'))
    lst.append(check_metric(true_label, prediction,'RMSE'))
    lst.append(check_metric(true_label, prediction,'R2'))
    lst.append(check_metric(true_label,prediction,'RMSLE'))
    lst.append(check_metric(true_label, prediction,'MAPE'))
    return lst

# %%
metrics_func(GBM_Carmustine_pred.LN_IC50_t, GBM_Carmustine_pred.Label)
# Out:
# [0.4341, 0.2297, 0.4792, -2.8837, 0.3273, 2.4723]

# %%
metrics_func(GBM_Temozolomide_pred.LN_IC50_t, GBM_Temozolomide_pred.Label)
# Out:
# [0.3202, 0.13, 0.3605, -2.0407, 0.2394, 0.843]

# %%
metrics_func(GBM_Crizotinib_pred.LN_IC50_t, GBM_Crizotinib_pred.Label)
# Out:
# [0.1422, 0.0367, 0.1916, 0.1858, 0.138, 0.3899]

# %%
metrics_func(t_pred.LN_IC50, t_pred.Label)
# Out:
# [0.4831, 0.374, 0.6116, 0.5901, 0.089, 0.0809]

# %%
GBM_Temozolomide_pred[['LN_IC50_t','Label']]
# Out:
#       LN_IC50_t     Label
# 1263   0.305961  0.752120
# 1264   0.180939  0.747971
# 1265   0.278118  0.765492
# 1266   0.536504  0.812003
# 1267   0.249143  0.789425
# 1268   0.432858  0.800461
# 1269   0.554860  0.798207
# 1270   0.657947  0.813941
# 1271   0.658134  0.800127
# 1272   0.618183  0.799429
# 1273   1.000000  0.870551
# 1274   0.605100  0.790949
# 1275   0.531562  0.786603
# 1276   0.528993  0.787604
# 1277   0.477557  0.787532
# 1278   0.356803  0.763253
# 1279   0.656876  0.831006
# 1280   0.000000  0.766138
# 1281   0.725197  0.812851
# 1282   0.372074  0.777362
# 1283   0.473812  0.785230
# 1284   0.242374  0.780356
# 1285   0.543294  0.784390
# 1286   0.617099  0.826812

# %%
t_pred.boxplot(column=['LN_IC50','Label'])
# Out:
# <AxesSubplot:>

# %%
t_pred = pd.DataFrame()
t_pred['LN_IC50_t'] = GBM_Temozolomide_pred['Label'].values

# %%
t_pred['LN_IC50'] = GBM_Temozolomide_pred['LN_IC50'].values

# %%
t_pred = predict_model(et_LNIC50, data=t_pred)

# %%
t_pred
# Out:
#     LN_IC50_t     Label   LN_IC50
# 0    0.752120  5.443117  5.499546
# 1    0.747971  5.365564  4.921946
# 2    0.765492  5.692942  5.370912
# 3    0.812003  6.561834  6.564647
# 4    0.789425  6.140061  5.237048
# 5    0.800461  6.346256  6.085808
# 6    0.798207  6.304176  6.649453
# 7    0.813941  6.598089  7.125711
# 8    0.800127  6.340008  7.126576
# 9    0.799429  6.326957  6.942005
# 10   0.870551  7.655643  8.705989
# 11   0.790949  6.168532  6.881559
# 12   0.786603  6.087338  6.541817
# 13   0.787604  6.106059  6.529949
# 14   0.787532  6.104692  6.292316
# 15   0.763253  5.651108  5.734434
# 16   0.831006  6.916879  7.120765
# 17   0.766138  5.705003  4.086014
# 18   0.812851  6.577741  7.436404
# 19   0.777362  5.914696  5.804988
# 20   0.785230  6.061706  6.275015
# 21   0.780356  5.970632  5.205777
# 22   0.784390  6.046003  6.596017
# 23   0.826812  6.838573  6.936998

# %%
GBM_Carmustine_pred[['LN_IC50_t','Label']]
# Out:
#       LN_IC50_t     Label
# 2441   0.376723  0.766900
# 2442   0.000000  0.755884
# 2443   0.113863  0.775955
# 2444   0.592539  0.824784
# 2445   0.060814  0.797203
# 2446   0.643825  0.811025
# 2447   0.525624  0.808801
# 2448   0.505785  0.826179
# 2449   0.411207  0.803624
# 2450   0.139623  0.811764
# 2451   1.000000  0.873637
# 2452   0.600864  0.799028
# 2453   0.173046  0.770442
# 2454   0.169095  0.796114
# 2455   0.226922  0.793127
# 2456   0.288851  0.795547
# 2457   0.342854  0.776210
# 2458   0.610051  0.837948
# 2459   0.064150  0.777647
# 2460   0.720313  0.823298
# 2461   0.244391  0.789760
# 2462   0.348212  0.793612
# 2463   0.177905  0.787595
# 2464   0.449452  0.793873
# 2465   0.632502  0.828773

# %%
GBM_Carmustine_pred.boxplot(column=['LN_IC50_t','Label'])
# Out:
# <AxesSubplot:>

# %%
unseen_predict.columns
# Out:
# Index(['mol8 mol8 mol5 mol5 mol8 mol8',
#        'mol1 mol8 mol5 mol8 mol5 mol5 mol8 mol5',
#        'mol1 mol8 mol5 mol8 mol5 mol5 mol8',
#        'mol5 mol8 mol5 mol5 mol8 mol5 mol8 mol8',
#        'mol1 mol8 mol8 mol5 mol5 mol8 mol5 mol5', 'mol8 mol8 mol1 mol1',
#        'mol8 mol1 mol8 mol5 mol1 mol8 mol5',
#        'mol1 mol8 mol8 mol5 mol1 mol8 mol8', 'mol5 mol8 mol5 mol1',
#        'mol8 mol5 mol8 mol5 mol8 mol5 mol8 mol5',
#        ...
#        'BCL9L', 'ETV5', 'CARD11', 'DEK', 'HRAS', 'CBLC', 'TCGA_DESC',
#        'LN_IC50', 'LN_IC50_t', 'Label'],
#       dtype='object', length=1308)

# %%
unseen_predict.boxplot(column=['LN_IC50_t','Label'],by=['TCGA_DESC'],rot=45, )
# Out:
# array([<AxesSubplot:title={'center':'LN_IC50_t'}, xlabel='[TCGA_DESC]'>,
#        <AxesSubplot:title={'center':'Label'}, xlabel='[TCGA_DESC]'>],
#       dtype=object)

# %%
unseen_predict['LN_IC50_Pred'] = qt1.inverse_transform(
    unseen_predict['LN_IC50_t'].values.reshape(-1, 1))

# %%
unseen_predict.boxplot(column=['LN_IC50','LN_IC50_Pred'],by=['TCGA_DESC'],rot=45, )
# Out:
# array([<AxesSubplot:title={'center':'LN_IC50'}, xlabel='[TCGA_DESC]'>,
#        <AxesSubplot:title={'center':'LN_IC50_Pred'}, xlabel='[TCGA_DESC]'>],
#       dtype=object)

# %%
unseen_predict.boxplot(column=['LN_IC50_t','Label'],by=['TCGA_DESC'],rot=45, )
# Out:
# array([<AxesSubplot:title={'center':'LN_IC50_t'}, xlabel='[TCGA_DESC]'>,
#        <AxesSubplot:title={'center':'Label'}, xlabel='[TCGA_DESC]'>],
#       dtype=object)

# %%
unseen_predict['LN_IC50_Pred'] = qt1.inverse_transform(
    unseen_predict['Label'].values.reshape(-1, 1))

# %%
unseen_predict.boxplot(column=['LN_IC50','LN_IC50_Pred'],by=['TCGA_DESC'],rot=45, )
# Out:
# array([<AxesSubplot:title={'center':'LN_IC50'}, xlabel='[TCGA_DESC]'>,
#        <AxesSubplot:title={'center':'LN_IC50_Pred'}, xlabel='[TCGA_DESC]'>],
#       dtype=object)
