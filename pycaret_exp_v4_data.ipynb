# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import QuantileTransformer, quantile_transform
from sklearn.metrics import mean_absolute_error,mean_squared_error,  r2_score
from pycaret.regression import *
from pycaret.utils import check_metric

# %% [markdown]
# # Load Data

# %%
panCancer_train_df = pd.read_csv('../../D2GNets/data/panCancer_train_CGC_657_DR_Drug_features_new_df.csv')
GBM_train_df = pd.read_csv('../../D2GNets/data/GBM_train_CGC_657_DR_Drug_features_new_df.csv')

# %% [markdown]
# # Feature Engineeing (Step-2)

# %%
# Removing Features based on Feature Score less than 70
featureScore = pd.read_csv('../../D2GNets/supplementary_material/featureScore.csv')
featureScore = featureScore[featureScore['Score']>=70]
features = set(featureScore['Name'].to_list())

# %%
# Getting the column names
disease_cols = (pd.read_csv('../../D2GNets/data/diseaseNames.csv')).columns.tolist()
GE_cols =  (pd.read_csv('../../D2GNets/data/657_Gene_name.csv')).columns.tolist()
drug_cols =  (pd.read_csv('../../D2GNets/data/moleculeNames_v1.csv')).columns.tolist()

Drug_Xcols = list(features.intersection(set(drug_cols)))+disease_cols
GE_Xcols = GE_cols#list(features.intersection(set(panCancer_train_df.columns[55+2986:].to_list())))

# %%
print(f"No. of Diseases: {len(disease_cols)}")
print(f"No. of Drugs Features: {len(Drug_Xcols)}")
print(f"No. of GENEs: {len(GE_Xcols)}")
# Out:
# No. of Diseases: 31
# No. of Drugs Features: 1999
# No. of GENEs: 657

# %% [markdown]
# # Data Preparation for ML operation

# %% [markdown]
# ### Data for Drug Repurposing Experiments

# %%
GBM_test_Carmustine = GBM_train_df[GBM_train_df['DRUG_NAME']=='Carmustine'].copy(deep=True)
GBM_test_Temozolomide = GBM_train_df[GBM_train_df['DRUG_NAME']=='Temozolomide'].copy(deep=True)

# %% [markdown]
# ### Data for Drug Screening Experiments

# %%
indx_4_drugs = (GBM_test_Carmustine.index.to_list()+
 GBM_test_Temozolomide.index.to_list())
GBM_train_df.drop(index=indx_4_drugs,inplace=True)

# %%
panCancer_df = pd.concat([panCancer_train_df,GBM_train_df],axis=0)
panCancer_df = panCancer_df[Drug_Xcols+GE_Xcols+['TCGA_DESC','LN_IC50','SAMPLE_ID','DRUG_NAME']]
panCancer_df.dropna(inplace=True)

# %%
train = panCancer_df.sample(frac=0.8).copy(deep=True)# Training data for Drug Screening
test = panCancer_df.drop(index=train.index).copy(deep=True) # Test Data for Drug Screening

# %%
print(f"Train data size: {train.shape[0]}")
print(f"Test data size: {test.shape[0]}")
# Out:
# Train data size: 96219
# Test data size: 22845

# %% [markdown]
# # Quantile Transformation of Target (LN_IC50)

# %%
qt1 = QuantileTransformer(n_quantiles=2, random_state=42,output_distribution='uniform')
#qt2 = QuantileTransformer(n_quantiles=200, random_state=0)

train['LN_IC50_t'] = qt1.fit_transform(
    train['LN_IC50'].values.reshape(-1, 1))
test['LN_IC50_t'] = qt1.fit_transform(
    test['LN_IC50'].values.reshape(-1, 1))

#test_unseen['LN_IC50_t'] = qt1.fit_transform(test_unseen['LN_IC50'].values.reshape(-1, 1))

GBM_test_Carmustine['LN_IC50_t'] = qt1.fit_transform(GBM_test_Carmustine['LN_IC50'].values.reshape(-1, 1))
GBM_test_Temozolomide['LN_IC50_t'] = qt1.fit_transform(GBM_test_Temozolomide['LN_IC50'].values.reshape(-1, 1))

# %% [markdown]
# # Random Forest Model for Quantile Inverse Transformation

# %%
exp1 = setup(data=train[['LN_IC50_t','LN_IC50']], target='LN_IC50', test_data=test[['LN_IC50_t','LN_IC50']],numeric_features=['LN_IC50_t']
           ,transformation = False, normalize=False,use_gpu=True,polynomial_features=True,polynomial_degree=3)
# Out:
# <style type="text/css">
# #T_13b8e_row16_col1, #T_13b8e_row42_col1, #T_13b8e_row45_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_13b8e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13b8e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13b8e_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_13b8e_row0_col1" class="data row0 col1" >930</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_13b8e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_13b8e_row1_col1" class="data row1 col1" >LN_IC50</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_13b8e_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_13b8e_row2_col1" class="data row2 col1" >(96219, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_13b8e_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_13b8e_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_13b8e_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_13b8e_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_13b8e_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_13b8e_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_13b8e_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_13b8e_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_13b8e_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_13b8e_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_13b8e_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_13b8e_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_13b8e_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_13b8e_row9_col1" class="data row9 col1" >(96219, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_13b8e_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_13b8e_row10_col1" class="data row10 col1" >(22845, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_13b8e_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_13b8e_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_13b8e_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_13b8e_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_13b8e_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_13b8e_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_13b8e_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_13b8e_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_13b8e_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_13b8e_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_13b8e_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_13b8e_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_13b8e_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_13b8e_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_13b8e_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_13b8e_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_13b8e_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_13b8e_row19_col1" class="data row19 col1" >49bb</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_13b8e_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_13b8e_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_13b8e_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_13b8e_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_13b8e_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_13b8e_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_13b8e_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_13b8e_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_13b8e_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_13b8e_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_13b8e_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_13b8e_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_13b8e_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_13b8e_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_13b8e_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_13b8e_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_13b8e_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_13b8e_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_13b8e_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_13b8e_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_13b8e_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_13b8e_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_13b8e_row30_col1" class="data ro

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_905f9_ th {
#   text-align: left;
# }
# #T_905f9_row0_col0, #T_905f9_row1_col0, #T_905f9_row2_col0, #T_905f9_row2_col1, #T_905f9_row2_col3, #T_905f9_row2_col5, #T_905f9_row2_col6, #T_905f9_row3_col0, #T_905f9_row4_col0, #T_905f9_row5_col0, #T_905f9_row6_col0, #T_905f9_row6_col1, #T_905f9_row6_col3, #T_905f9_row6_col5, #T_905f9_row6_col6, #T_905f9_row7_col0, #T_905f9_row7_col1, #T_905f9_row7_col3, #T_905f9_row7_col5, #T_905f9_row7_col6, #T_905f9_row8_col0, #T_905f9_row8_col1, #T_905f9_row8_col3, #T_905f9_row8_col5, #T_905f9_row8_col6, #T_905f9_row9_col0, #T_905f9_row9_col3, #T_905f9_row9_col5, #T_905f9_row10_col0, #T_905f9_row10_col1, #T_905f9_row10_col2, #T_905f9_row10_col3, #T_905f9_row10_col4, #T_905f9_row10_col5, #T_905f9_row10_col6, #T_905f9_row11_col0, #T_905f9_row11_col1, #T_905f9_row11_col2, #T_905f9_row11_col3, #T_905f9_row11_col4, #T_905f9_row11_col5, #T_905f9_row11_col6, #T_905f9_row12_col0, #T_905f9_row12_col1, #T_905f9_row12_col2, #T_905f9_row12_col3, #T_905f9_row12_col4, #T_905f9_row12_col5, #T_905f9_row12_col6, #T_905f9_row13_col0, #T_905f9_row13_col1, #T_905f9_row13_col2, #T_905f9_row13_col3, #T_905f9_row13_col4, #T_905f9_row13_col5, #T_905f9_row13_col6, #T_905f9_row14_col0, #T_905f9_row14_col1, #T_905f9_row14_col2, #T_905f9_row14_col3, #T_905f9_row14_col4, #T_905f9_row14_col5, #T_905f9_row14_col6, #T_905f9_row15_col0, #T_905f9_row15_col1, #T_905f9_row15_col2, #T_905f9_row15_col3, #T_905f9_row15_col4, #T_905f9_row15_col5, #T_905f9_row15_col6, #T_905f9_row16_col0, #T_905f9_row16_col1, #T_905f9_row16_col2, #T_905f9_row16_col3, #T_905f9_row16_col4, #T_905f9_row16_col5, #T_905f9_row16_col6, #T_905f9_row17_col0, #T_905f9_row17_col1, #T_905f9_row17_col2, #T_905f9_row17_col3, #T_905f9_row17_col4, #T_905f9_row17_col5, #T_905f9_row17_col6 {
#   text-align: left;
# }
# #T_905f9_row0_col1, #T_905f9_row0_col2, #T_905f9_row0_col3, #T_905f9_row0_col4, #T_905f9_row0_col5, #T_905f9_row0_col6, #T_905f9_row1_col1, #T_905f9_row1_col2, #T_905f9_row1_col3, #T_905f9_row1_col4, #T_905f9_row1_col5, #T_905f9_row1_col6, #T_905f9_row2_col2, #T_905f9_row2_col4, #T_905f9_row3_col1, #T_905f9_row3_col2, #T_905f9_row3_col3, #T_905f9_row3_col4, #T_905f9_row3_col5, #T_905f9_row3_col6, #T_905f9_row4_col1, #T_905f9_row4_col2, #T_905f9_row4_col3, #T_905f9_row4_col4, #T_905f9_row4_col5, #T_905f9_row4_col6, #T_905f9_row5_col1, #T_905f9_row5_col2, #T_905f9_row5_col3, #T_905f9_row5_col4, #T_905f9_row5_col5, #T_905f9_row5_col6, #T_905f9_row6_col2, #T_905f9_row6_col4, #T_905f9_row7_col2, #T_905f9_row7_col4, #T_905f9_row8_col2, #T_905f9_row8_col4, #T_905f9_row9_col1, #T_905f9_row9_col2, #T_905f9_row9_col4, #T_905f9_row9_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_905f9_row0_col7, #T_905f9_row1_col7, #T_905f9_row2_col7, #T_905f9_row3_col7, #T_905f9_row4_col7, #T_905f9_row5_col7, #T_905f9_row6_col7, #T_905f9_row7_col7, #T_905f9_row8_col7, #T_905f9_row9_col7, #T_905f9_row10_col7, #T_905f9_row11_col7, #T_905f9_row12_col7, #T_905f9_row13_col7, #T_905f9_row14_col7, #T_905f9_row15_col7, #T_905f9_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_905f9_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_905f9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_905f9_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_905f9_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_905f9_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_905f9_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_905f9_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_905f9_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_905f9_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_905f9_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_905f9_row0_col7" class="data row0 col7" >0.0240</td>
#     </tr>
#     <tr>
#       <th id="T_905f9_level0_row1" class="row_heading level0 row1" >huber</th>
#       <td id="T_905f9_row1_col0" class="data row1 col0" >Huber Regressor</td>
#       <td id="T_905f9_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_905f9_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_905f9_row1_col3" class="data row1 col3" >0.0000</td>
#       <td id="T_905f9_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_905f9_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_905f9_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_905f9_row1_col7" class="data row1 col7" >0.4550</td>
#     </tr>
#     <tr>
#       <th id="T_905f9_level0_row2" class="row_heading level0 row2" >knn</th>
#       <td id="T_905f9_row2_col0" class="data row2 col0" >K Neighbors Regressor</td>
#       <td id="T_905f9_row2_col1" class="data row2 col1" >0.0001</td>
#       <td id="T_905f9_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_905f9_row2_col3" class="data row2 col3" >0.0015</td>
#       <td id="T_905f9_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_905f9_row2_col5" class="data row2 col5" >0.0002</td>
#       <td id="T_905f9_row2_col6" class="data row2 col6" >0.0002</td>
#       <td id="T_905f9_row2_col7" class="data row2 col7" >1.3570</td>
#     </tr>
#     <tr>
#       <th id="T_905f9_level0_row3" class="row_heading level0 row3" >omp</th>
#       <td id="T_905f9_row3_col0" class="data row3 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_905f9_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_905f9_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_905f9_row3_col3" class="data row3 col3" >0.0000</td>
#       <td id="T_905f9_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_905f9_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_905f9_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_905f9_row3_col7" class="data row3 col7" >0.0080</td>
#     </tr>
#     <tr>
#       <th id="T_905f9_level0_row4" class="row_heading level0 row4" >br</th>
#       <td id="T_905f9_row4_col0" class="data row4 col0" >Bayesian Ridge</td>
#       <td id="T_905f9_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_905f9_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_905f9_row4_col3" class="data row4 col3" >0.0000</td>
#       <td id="T_905f9_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_905f9_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_905f9_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_905f9_row4_col7" class="data row4 col7" >0.0300</td>
#     </tr>
#     <tr>
#       <th id="T_905f9_level0_row5" class="row_heading level0 row5" >lar</th>
#       <td id="T_905f9_row5_col0" class="data row5 col0" >Least Angle Regression</td>
#       <td id="T_905f9_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_905f9_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_905f9_row5_col3" class="data row5 col3" >0.0000</td>
#       <td id="T_905f9_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_905f9_row5_col5" class="data row5 col5" >0.0000</td>
#       <td id="T_905f9_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_905f9_row5_col7" class="data row5 col7" >0.0080</td>
#     </tr>
#     <tr>
#       <th id="T_905f9_level0_row6" class="row_heading level0 row6" >rf</th>
#       <td id="T_905f9_row6_col0" class="data row6 col0" >Random Forest Regressor</td>
#       <td id="T_905f9_row6_col1" class="data row6 col1" >0.0001</td>
#       <td id="T_905f9_row6

# %%
et_LNIC50 = create_model('et')
# Out:
# <style type="text/css">
# #T_0836c_row10_col0, #T_0836c_row10_col1, #T_0836c_row10_col2, #T_0836c_row10_col3, #T_0836c_row10_col4, #T_0836c_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_0836c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0836c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0836c_row0_col0" class="data row0 col0" >0.0000</td>
#       <td id="T_0836c_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_0836c_row0_col2" class="data row0 col2" >0.0001</td>
#       <td id="T_0836c_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_0836c_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_0836c_row0_col5" class="data row0 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0836c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0836c_row1_col0" class="data row1 col0" >0.0001</td>
#       <td id="T_0836c_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_0836c_row1_col2" class="data row1 col2" >0.0044</td>
#       <td id="T_0836c_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_0836c_row1_col4" class="data row1 col4" >0.0004</td>
#       <td id="T_0836c_row1_col5" class="data row1 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0836c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0836c_row2_col0" class="data row2 col0" >0.0000</td>
#       <td id="T_0836c_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_0836c_row2_col2" class="data row2 col2" >0.0001</td>
#       <td id="T_0836c_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_0836c_row2_col4" class="data row2 col4" >0.0000</td>
#       <td id="T_0836c_row2_col5" class="data row2 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0836c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0836c_row3_col0" class="data row3 col0" >0.0000</td>
#       <td id="T_0836c_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_0836c_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_0836c_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_0836c_row3_col4" class="data row3 col4" >0.0000</td>
#       <td id="T_0836c_row3_col5" class="data row3 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0836c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0836c_row4_col0" class="data row4 col0" >0.0000</td>
#       <td id="T_0836c_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_0836c_row4_col2" class="data row4 col2" >0.0001</td>
#       <td id="T_0836c_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_0836c_row4_col4" class="data row4 col4" >0.0000</td>
#       <td id="T_0836c_row4_col5" class="data row4 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0836c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0836c_row5_col0" class="data row5 col0" >0.0000</td>
#       <td id="T_0836c_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_0836c_row5_col2" class="data row5 col2" >0.0016</td>
#       <td id="T_0836c_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_0836c_row5_col4" class="data row5 col4" >0.0002</td>
#       <td id="T_0836c_row5_col5" class="data row5 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0836c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0836c_row6_col0" class="data row6 col0" >0.0000</td>
#       <td id="T_0836c_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_0836c_row6_col2" class="data row6 col2" >0.0001</td>
#       <td id="T_0836c_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_0836c_row6_col4" class="data row6 col4" >0.0000</td>
#       <td id="T_0836c_row6_col5" class="data row6 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0836c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0836c_row7_col0" class="data row7 col0" >0.0000</td>
#       <td id="T_0836c_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_0836c_row7_col2" class="data row7 col2" >0.0003</td>
#       <td id="T_0836c_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_0836c_row7_col4" class="data row7 col4" >0.0000</td>
#       <td id="T_0836c_row7_col5" class="data row7 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0836c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0836c_row8_col0" class="data row8 col0" >0.0000</td>
#       <td id="T_0836c_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_0836c_row8_col2" class="data row8 col2" >0.0001</td>
#       <td id="T_0836c_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_0836c_row8_col4" class="data row8 col4" >0.0000</td>
#       <td id="T_0836c_row8_col5" class="data row8 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0836c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0836c_row9_col0" class="data row9 col0" >0.0000</td>
#       <td id="T_0836c_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_0836c_row9_col2" class="data row9 col2" >0.0001</td>
#       <td id="T_0836c_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_0836c_row9_col4" class="data row9 col4" >0.0000</td>
#       <td id="T_0836c_row9_col5" class="data row9 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0836c_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_0836c_row10_col0" class="data row10 col0" >0.0000</td>
#       <td id="T_0836c_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_0836c_row10_col2" class="data row10 col2" >0.0007</td>
#       <td id="T_0836c_row10_col3" class="data row10 col3" >1.0000</td>
#       <td id="T_0836c_row10_col4" class="data row10 col4" >0.0001</td>
#       <td id="T_0836c_row10_col5" class="data row10 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0836c_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_0836c_row11_col0" class="data row11 col0" >0.0000</td>
#       <td id="T_0836c_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_0836c_row11_col2" class="data row11 col2" >0.0013</td>
#       <td id="T_0836c_row11_col3" class="data row11 col3" >0.0000</td>
#       <td id="T_0836c_row11_col4" class="data row11 col4" >0.0001</td>
#       <td id="T_0836c_row11_col5" class="data row11 col5" >0.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
et_res= pull()

# %%
et_res.to_csv('../../D2GNets/result/LabelModel10fold.csv')

# %%
predict_model(et_LNIC50);
# Out:
# <style type="text/css">
# </style>
# <table id="T_397ca_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_397ca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_397ca_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_397ca_row0_col1" class="data row0 col1" >0.0719</td>
#       <td id="T_397ca_row0_col2" class="data row0 col2" >0.0068</td>
#       <td id="T_397ca_row0_col3" class="data row0 col3" >0.0823</td>
#       <td id="T_397ca_row0_col4" class="data row0 col4" >0.9991</td>
#       <td id="T_397ca_row0_col5" class="data row0 col5" >0.0327</td>
#       <td id="T_397ca_row0_col6" class="data row0 col6" >0.1459</td>
#     </tr>
#   </tbody>
# </table>

# %%
final_et_LNIC50 = finalize_model(et_LNIC50)

# %%
save_model(final_et_LNIC50,'../../D2GNets/models/LNIC50_Model/Final_et_LNIC50_Model_25June2022')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=['LN_IC50_t'],
#                                        target='LN_IC50', time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numer...
#                   ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0,
#                                       criterion='mse', max_depth=None,
#                                       max_features='auto', max_leaf_nodes=None,
#                                       max_samples=None,
#                                       min_impurity_decrease=0.0,
#                                       min_impurity_split=None,
#                                       min_samples_leaf=1, min_samples_split=2,
#                                       min_weight_fraction_leaf=0.0,
#                                       n_estimators=100, n_jobs=-1,
#                                       oob_score=False, random_state=930,
#                                       verbose=0, warm_start=False)]],
#           verbose=False),
#  '../../D2GNets/models/LNIC50_Model/Final_et_LNIC50_Model_25June2022.pkl')

# %% [markdown]
# # Drug Screening Model development

# %%
exp = setup(data=train, target='LN_IC50_t', test_data=test,  ignore_features=['TCGA_DESC','LN_IC50','SAMPLE_ID','DRUG_NAME'],numeric_features=disease_cols+Drug_Xcols+GE_Xcols
           ,transformation = False, normalize=False,use_gpu=True)
# Out:
# <style type="text/css">
# #T_62441_row16_col1, #T_62441_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_62441_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62441_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_62441_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_62441_row0_col1" class="data row0 col1" >6778</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_62441_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_62441_row1_col1" class="data row1 col1" >LN_IC50_t</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_62441_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_62441_row2_col1" class="data row2 col1" >(96219, 2661)</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_62441_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_62441_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_62441_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_62441_row4_col1" class="data row4 col1" >2656</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_62441_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_62441_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_62441_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_62441_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_62441_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_62441_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_62441_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_62441_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_62441_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_62441_row9_col1" class="data row9 col1" >(96219, 1313)</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_62441_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_62441_row10_col1" class="data row10 col1" >(22809, 1313)</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_62441_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_62441_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_62441_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_62441_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_62441_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_62441_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_62441_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_62441_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_62441_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_62441_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_62441_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_62441_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_62441_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_62441_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_62441_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_62441_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_62441_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_62441_row19_col1" class="data row19 col1" >8d47</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_62441_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_62441_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_62441_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_62441_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_62441_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_62441_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_62441_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_62441_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_62441_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_62441_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_62441_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_62441_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_62441_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_62441_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_62441_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_62441_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_62441_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_62441_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_62441_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_62441_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_62441_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_62441_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_62441_row30_col1" class="data row30 co

# %%
models()
# Out:
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
#                                        Name  \
# ID
# lr                        Linear Regression
# lasso                      Lasso Regression
# ridge                      Ridge Regression
# en                              Elastic Net
# lar                  Least Angle Regression
# llar           Lasso Least Angle Regression
# omp             Orthogonal Matching Pursuit
# br                           Bayesian Ridge
# ard       Automatic Relevance Determination
# par            Passive Aggressive Regressor
# ransac              Random Sample Consensus
# tr                       TheilSen Regressor
# huber                       Huber Regressor
# kr                             Kernel Ridge
# svm               Support Vector Regression
# knn                   K Neighbors Regressor
# dt                  Decision Tree Regressor
# rf                  Random Forest Regressor
# et                    Extra Trees Regressor
# ada                      AdaBoost Regressor
# gbr             Gradient Boosting Regressor
# mlp                           MLP Regressor
# lightgbm    Light Gradient Boosting Machine
# dummy                       Dummy Regressor
#
#                                                   Reference  Turbo
# ID
# lr              sklearn.linear_model._base.LinearRegression   True
# lasso        sklearn.linear_model._coordinate_descent.Lasso   True
# ridge                     sklearn.linear_model._ridge.Ridge   True
# en        sklearn.linear_model._coordinate_descent.Elast...   True
# lar                  sklearn.linear_model._least_angle.Lars   True
# llar            sklearn.linear_model._least_angle.LassoLars   True
# omp       sklearn.linear_model._omp.OrthogonalMatchingPu...   True
# br                sklearn.linear_model._bayes.BayesianRidge   True
# ard               sklearn.linear_model._bayes.ARDRegression  False
# par       sklearn.linear_model._passive_aggressive.Passi...   True
# ransac         sklearn.linear_model._ransac.RANSACRegressor  False
# tr        sklearn.linear_model._theil_sen.TheilSenRegressor  False
# huber            sklearn.linear_model._huber.HuberRegressor   True
# kr                         sklearn.kernel_ridge.KernelRidge  False
# svm                                sklearn.svm._classes.SVR  False
# knn       sklearn.neighbors._regression.KNeighborsRegressor   True
# dt              sklearn.tree._classes.DecisionTreeRegressor   True
# rf           sklearn.ensemble._forest.RandomForestRegressor   True
# et             sklearn.ensemble._forest.ExtraTreesRegressor   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostRegr...   True
# gbr          sklearn.ensemble._gb.GradientBoostingRegressor   True
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# lightgbm                     lightgbm.sklearn.LGBMRegressor   True
# dummy                          sklearn.dummy.DummyRegressor   True
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1

# %%
mdl1= compare_models(include=['lr','knn','gbr','dt','ridge','ada','lasso','rf','lightgbm','et'])
# Out:
# <style type="text/css">
# #T_991fb_ th {
#   text-align: left;
# }
# #T_991fb_row0_col0, #T_991fb_row1_col0, #T_991fb_row1_col1, #T_991fb_row1_col2, #T_991fb_row1_col3, #T_991fb_row1_col4, #T_991fb_row1_col5, #T_991fb_row1_col6, #T_991fb_row2_col0, #T_991fb_row2_col1, #T_991fb_row2_col2, #T_991fb_row2_col3, #T_991fb_row2_col4, #T_991fb_row2_col5, #T_991fb_row2_col6, #T_991fb_row3_col0, #T_991fb_row3_col1, #T_991fb_row3_col2, #T_991fb_row3_col3, #T_991fb_row3_col4, #T_991fb_row3_col5, #T_991fb_row3_col6, #T_991fb_row4_col0, #T_991fb_row4_col1, #T_991fb_row4_col2, #T_991fb_row4_col3, #T_991fb_row4_col4, #T_991fb_row4_col5, #T_991fb_row4_col6, #T_991fb_row5_col0, #T_991fb_row5_col1, #T_991fb_row5_col2, #T_991fb_row5_col3, #T_991fb_row5_col4, #T_991fb_row5_col5, #T_991fb_row5_col6, #T_991fb_row6_col0, #T_991fb_row6_col1, #T_991fb_row6_col2, #T_991fb_row6_col3, #T_991fb_row6_col4, #T_991fb_row6_col5, #T_991fb_row6_col6, #T_991fb_row7_col0, #T_991fb_row7_col1, #T_991fb_row7_col2, #T_991fb_row7_col3, #T_991fb_row7_col4, #T_991fb_row7_col5, #T_991fb_row7_col6, #T_991fb_row8_col0, #T_991fb_row8_col1, #T_991fb_row8_col2, #T_991fb_row8_col3, #T_991fb_row8_col4, #T_991fb_row8_col5, #T_991fb_row8_col6, #T_991fb_row9_col0, #T_991fb_row9_col1, #T_991fb_row9_col2, #T_991fb_row9_col3, #T_991fb_row9_col4, #T_991fb_row9_col5, #T_991fb_row9_col6 {
#   text-align: left;
# }
# #T_991fb_row0_col1, #T_991fb_row0_col2, #T_991fb_row0_col3, #T_991fb_row0_col4, #T_991fb_row0_col5, #T_991fb_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_991fb_row0_col7, #T_991fb_row1_col7, #T_991fb_row2_col7, #T_991fb_row3_col7, #T_991fb_row4_col7, #T_991fb_row5_col7, #T_991fb_row6_col7, #T_991fb_row7_col7, #T_991fb_row8_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_991fb_row9_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_991fb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_991fb_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_991fb_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_991fb_row0_col1" class="data row0 col1" >0.0473</td>
#       <td id="T_991fb_row0_col2" class="data row0 col2" >0.0040</td>
#       <td id="T_991fb_row0_col3" class="data row0 col3" >0.0631</td>
#       <td id="T_991fb_row0_col4" class="data row0 col4" >0.8271</td>
#       <td id="T_991fb_row0_col5" class="data row0 col5" >0.0414</td>
#       <td id="T_991fb_row0_col6" class="data row0 col6" >0.0993</td>
#       <td id="T_991fb_row0_col7" class="data row0 col7" >15.5250</td>
#     </tr>
#     <tr>
#       <th id="T_991fb_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_991fb_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_991fb_row1_col1" class="data row1 col1" >0.0484</td>
#       <td id="T_991fb_row1_col2" class="data row1 col2" >0.0043</td>
#       <td id="T_991fb_row1_col3" class="data row1 col3" >0.0653</td>
#       <td id="T_991fb_row1_col4" class="data row1 col4" >0.8151</td>
#       <td id="T_991fb_row1_col5" class="data row1 col5" >0.0428</td>
#       <td id="T_991fb_row1_col6" class="data row1 col6" >0.1005</td>
#       <td id="T_991fb_row1_col7" class="data row1 col7" >524.7860</td>
#     </tr>
#     <tr>
#       <th id="T_991fb_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_991fb_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_991fb_row2_col1" class="data row2 col1" >0.0482</td>
#       <td id="T_991fb_row2_col2" class="data row2 col2" >0.0043</td>
#       <td id="T_991fb_row2_col3" class="data row2 col3" >0.0653</td>
#       <td id="T_991fb_row2_col4" class="data row2 col4" >0.8148</td>
#       <td id="T_991fb_row2_col5" class="data row2 col5" >0.0430</td>
#       <td id="T_991fb_row2_col6" class="data row2 col6" >0.0997</td>
#       <td id="T_991fb_row2_col7" class="data row2 col7" >323.4130</td>
#     </tr>
#     <tr>
#       <th id="T_991fb_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_991fb_row3_col0" class="data row3 col0" >Ridge Regression</td>
#       <td id="T_991fb_row3_col1" class="data row3 col1" >0.0502</td>
#       <td id="T_991fb_row3_col2" class="data row3 col2" >0.0045</td>
#       <td id="T_991fb_row3_col3" class="data row3 col3" >0.0672</td>
#       <td id="T_991fb_row3_col4" class="data row3 col4" >0.8043</td>
#       <td id="T_991fb_row3_col5" class="data row3 col5" >0.0441</td>
#       <td id="T_991fb_row3_col6" class="data row3 col6" >0.1056</td>
#       <td id="T_991fb_row3_col7" class="data row3 col7" >4.7370</td>
#     </tr>
#     <tr>
#       <th id="T_991fb_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_991fb_row4_col0" class="data row4 col0" >Linear Regression</td>
#       <td id="T_991fb_row4_col1" class="data row4 col1" >0.0503</td>
#       <td id="T_991fb_row4_col2" class="data row4 col2" >0.0045</td>
#       <td id="T_991fb_row4_col3" class="data row4 col3" >0.0673</td>
#       <td id="T_991fb_row4_col4" class="data row4 col4" >0.8034</td>
#       <td id="T_991fb_row4_col5" class="data row4 col5" >0.0442</td>
#       <td id="T_991fb_row4_col6" class="data row4 col6" >0.1058</td>
#       <td id="T_991fb_row4_col7" class="data row4 col7" >3.6330</td>
#     </tr>
#     <tr>
#       <th id="T_991fb_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_991fb_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_991fb_row5_col1" class="data row5 col1" >0.0602</td>
#       <td id="T_991fb_row5_col2" class="data row5 col2" >0.0061</td>
#       <td id="T_991fb_row5_col3" class="data row5 col3" >0.0780</td>
#       <td id="T_991fb_row5_col4" class="data row5 col4" >0.7365</td>
#       <td id="T_991fb_row5_col5" class="data row5 col5" >0.0512</td>
#       <td id="T_991fb_row5_col6" class="data row5 col6" >0.1300</td>
#       <td id="T_991fb_row5_col7" class="data row5 col7" >713.5630</td>
#     </tr>
#     <tr>
#       <th id="T_991fb_level0_row6" class="row_heading level0 row6" >dt</th>
#       <td id="T_991fb_row6_col0" class="data row6 col0" >Decision Tree Regressor</td>
#       <td id="T_991fb_row6_col1" class="data row6 col1" >0.0688</td>
#       <td id="T_991fb_row6_col2" class="data row6 col2" >0.0087</td>
#       <td id="T_991fb_row6_col3" class="data row6 col3" >0.0930</td>
#       <td id="T_991fb_row6_col4" class="data row6 col4" >0.6247</td>
#       <td id="T_991fb_row6_col5" class="data row6 col5" >0.0607</td>
#       <td id="T_991fb_row6_col6" class="data row6 col6" >0.1382</td>
#       <td id="T_991fb_row6_col7" class="data row6 col7" >72.6800</td>
#     </tr>
#     <tr>
#       <th id="T_991fb_level0_row7" class="row_heading level0 row7" >knn</th>
#       <td id="T_991fb_row7_col0" class="data row7 col0" >K Neighbors Regressor</td>
#       <td id="T_991fb_row7_col1" class="data row7 col1" >0.0840</td>
#       <td id="T_991fb_row7_col2" class="data row7 col2" >0.0133</td>
#       <td id="T_991fb_row7_col3" class="data row7 col3" >0.1153</td>
#       <td id="T_991fb_row7_col4" class="data row7 col4" >0.4236</td>
#       <td id="T_991fb_row7_col5" class="data row7 col5" >0.0762</td>
#       <td id="T_991fb_row7_col6" class="data row7 col6" >0.1934</td>
#       <td id="T_991fb_row7_col7" class="data row7 col7" >211.9050</td>
#     </tr>
#     <tr>
#       <th id="T_991fb_level0_row8" class="row_heading level0 row8" >ada</th>
#       <td id="T_991fb_row8_col0" class="data row8 col0" >AdaBoost Regressor</td>
#       <td id="T_991fb_row8_col1" class="data row8 col1" >0.0982</td>
#       <td id="

# %%
#mdl1_1 = pull()
#mdl1_1.to_csv('../../D2GNets/result/modelSelection.csv')

# %%
lr = create_model('lr')
# Out:
# <style type="text/css">
# #T_36758_row10_col0, #T_36758_row10_col1, #T_36758_row10_col2, #T_36758_row10_col3, #T_36758_row10_col4, #T_36758_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_36758_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36758_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_36758_row0_col0" class="data row0 col0" >0.0502</td>
#       <td id="T_36758_row0_col1" class="data row0 col1" >0.0045</td>
#       <td id="T_36758_row0_col2" class="data row0 col2" >0.0671</td>
#       <td id="T_36758_row0_col3" class="data row0 col3" >0.7994</td>
#       <td id="T_36758_row0_col4" class="data row0 col4" >0.0440</td>
#       <td id="T_36758_row0_col5" class="data row0 col5" >0.1071</td>
#     </tr>
#     <tr>
#       <th id="T_36758_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_36758_row1_col0" class="data row1 col0" >0.0499</td>
#       <td id="T_36758_row1_col1" class="data row1 col1" >0.0045</td>
#       <td id="T_36758_row1_col2" class="data row1 col2" >0.0668</td>
#       <td id="T_36758_row1_col3" class="data row1 col3" >0.8075</td>
#       <td id="T_36758_row1_col4" class="data row1 col4" >0.0439</td>
#       <td id="T_36758_row1_col5" class="data row1 col5" >0.1056</td>
#     </tr>
#     <tr>
#       <th id="T_36758_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_36758_row2_col0" class="data row2 col0" >0.0497</td>
#       <td id="T_36758_row2_col1" class="data row2 col1" >0.0044</td>
#       <td id="T_36758_row2_col2" class="data row2 col2" >0.0665</td>
#       <td id="T_36758_row2_col3" class="data row2 col3" >0.8080</td>
#       <td id="T_36758_row2_col4" class="data row2 col4" >0.0435</td>
#       <td id="T_36758_row2_col5" class="data row2 col5" >0.1025</td>
#     </tr>
#     <tr>
#       <th id="T_36758_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_36758_row3_col0" class="data row3 col0" >0.0507</td>
#       <td id="T_36758_row3_col1" class="data row3 col1" >0.0046</td>
#       <td id="T_36758_row3_col2" class="data row3 col2" >0.0678</td>
#       <td id="T_36758_row3_col3" class="data row3 col3" >0.8034</td>
#       <td id="T_36758_row3_col4" class="data row3 col4" >0.0445</td>
#       <td id="T_36758_row3_col5" class="data row3 col5" >0.1071</td>
#     </tr>
#     <tr>
#       <th id="T_36758_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_36758_row4_col0" class="data row4 col0" >0.0498</td>
#       <td id="T_36758_row4_col1" class="data row4 col1" >0.0044</td>
#       <td id="T_36758_row4_col2" class="data row4 col2" >0.0664</td>
#       <td id="T_36758_row4_col3" class="data row4 col3" >0.8111</td>
#       <td id="T_36758_row4_col4" class="data row4 col4" >0.0435</td>
#       <td id="T_36758_row4_col5" class="data row4 col5" >0.1028</td>
#     </tr>
#     <tr>
#       <th id="T_36758_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_36758_row5_col0" class="data row5 col0" >0.0510</td>
#       <td id="T_36758_row5_col1" class="data row5 col1" >0.0047</td>
#       <td id="T_36758_row5_col2" class="data row5 col2" >0.0686</td>
#       <td id="T_36758_row5_col3" class="data row5 col3" >0.7976</td>
#       <td id="T_36758_row5_col4" class="data row5 col4" >0.0450</td>
#       <td id="T_36758_row5_col5" class="data row5 col5" >0.1057</td>
#     </tr>
#     <tr>
#       <th id="T_36758_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_36758_row6_col0" class="data row6 col0" >0.0505</td>
#       <td id="T_36758_row6_col1" class="data row6 col1" >0.0046</td>
#       <td id="T_36758_row6_col2" class="data row6 col2" >0.0678</td>
#       <td id="T_36758_row6_col3" class="data row6 col3" >0.8010</td>
#       <td id="T_36758_row6_col4" class="data row6 col4" >0.0445</td>
#       <td id="T_36758_row6_col5" class="data row6 col5" >0.1070</td>
#     </tr>
#     <tr>
#       <th id="T_36758_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_36758_row7_col0" class="data row7 col0" >0.0496</td>
#       <td id="T_36758_row7_col1" class="data row7 col1" >0.0044</td>
#       <td id="T_36758_row7_col2" class="data row7 col2" >0.0663</td>
#       <td id="T_36758_row7_col3" class="data row7 col3" >0.8090</td>
#       <td id="T_36758_row7_col4" class="data row7 col4" >0.0436</td>
#       <td id="T_36758_row7_col5" class="data row7 col5" >0.1079</td>
#     </tr>
#     <tr>
#       <th id="T_36758_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_36758_row8_col0" class="data row8 col0" >0.0499</td>
#       <td id="T_36758_row8_col1" class="data row8 col1" >0.0044</td>
#       <td id="T_36758_row8_col2" class="data row8 col2" >0.0662</td>
#       <td id="T_36758_row8_col3" class="data row8 col3" >0.8093</td>
#       <td id="T_36758_row8_col4" class="data row8 col4" >0.0435</td>
#       <td id="T_36758_row8_col5" class="data row8 col5" >0.1037</td>
#     </tr>
#     <tr>
#       <th id="T_36758_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_36758_row9_col0" class="data row9 col0" >0.0497</td>
#       <td id="T_36758_row9_col1" class="data row9 col1" >0.0044</td>
#       <td id="T_36758_row9_col2" class="data row9 col2" >0.0665</td>
#       <td id="T_36758_row9_col3" class="data row9 col3" >0.8078</td>
#       <td id="T_36758_row9_col4" class="data row9 col4" >0.0437</td>
#       <td id="T_36758_row9_col5" class="data row9 col5" >0.1052</td>
#     </tr>
#     <tr>
#       <th id="T_36758_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_36758_row10_col0" class="data row10 col0" >0.0501</td>
#       <td id="T_36758_row10_col1" class="data row10 col1" >0.0045</td>
#       <td id="T_36758_row10_col2" class="data row10 col2" >0.0670</td>
#       <td id="T_36758_row10_col3" class="data row10 col3" >0.8054</td>
#       <td id="T_36758_row10_col4" class="data row10 col4" >0.0440</td>
#       <td id="T_36758_row10_col5" class="data row10 col5" >0.1055</td>
#     </tr>
#     <tr>
#       <th id="T_36758_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_36758_row11_col0" class="data row11 col0" >0.0004</td>
#       <td id="T_36758_row11_col1" class="data row11 col1" >0.0001</td>
#       <td id="T_36758_row11_col2" class="data row11 col2" >0.0008</td>
#       <td id="T_36758_row11_col3" class="data row11 col3" >0.0045</td>
#       <td id="T_36758_row11_col4" class="data row11 col4" >0.0005</td>
#       <td id="T_36758_row11_col5" class="data row11 col5" >0.0018</td>
#     </tr>
#   </tbody>
# </table>

# %%
lgbm = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_bc5f3_row10_col0, #T_bc5f3_row10_col1, #T_bc5f3_row10_col2, #T_bc5f3_row10_col3, #T_bc5f3_row10_col4, #T_bc5f3_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_bc5f3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc5f3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bc5f3_row0_col0" class="data row0 col0" >0.0474</td>
#       <td id="T_bc5f3_row0_col1" class="data row0 col1" >0.0040</td>
#       <td id="T_bc5f3_row0_col2" class="data row0 col2" >0.0634</td>
#       <td id="T_bc5f3_row0_col3" class="data row0 col3" >0.8280</td>
#       <td id="T_bc5f3_row0_col4" class="data row0 col4" >0.0415</td>
#       <td id="T_bc5f3_row0_col5" class="data row0 col5" >0.0974</td>
#     </tr>
#     <tr>
#       <th id="T_bc5f3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bc5f3_row1_col0" class="data row1 col0" >0.0475</td>
#       <td id="T_bc5f3_row1_col1" class="data row1 col1" >0.0041</td>
#       <td id="T_bc5f3_row1_col2" class="data row1 col2" >0.0638</td>
#       <td id="T_bc5f3_row1_col3" class="data row1 col3" >0.8323</td>
#       <td id="T_bc5f3_row1_col4" class="data row1 col4" >0.0421</td>
#       <td id="T_bc5f3_row1_col5" class="data row1 col5" >0.1036</td>
#     </tr>
#     <tr>
#       <th id="T_bc5f3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bc5f3_row2_col0" class="data row2 col0" >0.0476</td>
#       <td id="T_bc5f3_row2_col1" class="data row2 col1" >0.0041</td>
#       <td id="T_bc5f3_row2_col2" class="data row2 col2" >0.0637</td>
#       <td id="T_bc5f3_row2_col3" class="data row2 col3" >0.8207</td>
#       <td id="T_bc5f3_row2_col4" class="data row2 col4" >0.0416</td>
#       <td id="T_bc5f3_row2_col5" class="data row2 col5" >0.0969</td>
#     </tr>
#     <tr>
#       <th id="T_bc5f3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bc5f3_row3_col0" class="data row3 col0" >0.0474</td>
#       <td id="T_bc5f3_row3_col1" class="data row3 col1" >0.0039</td>
#       <td id="T_bc5f3_row3_col2" class="data row3 col2" >0.0628</td>
#       <td id="T_bc5f3_row3_col3" class="data row3 col3" >0.8292</td>
#       <td id="T_bc5f3_row3_col4" class="data row3 col4" >0.0413</td>
#       <td id="T_bc5f3_row3_col5" class="data row3 col5" >0.1032</td>
#     </tr>
#     <tr>
#       <th id="T_bc5f3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bc5f3_row4_col0" class="data row4 col0" >0.0475</td>
#       <td id="T_bc5f3_row4_col1" class="data row4 col1" >0.0040</td>
#       <td id="T_bc5f3_row4_col2" class="data row4 col2" >0.0633</td>
#       <td id="T_bc5f3_row4_col3" class="data row4 col3" >0.8240</td>
#       <td id="T_bc5f3_row4_col4" class="data row4 col4" >0.0415</td>
#       <td id="T_bc5f3_row4_col5" class="data row4 col5" >0.0984</td>
#     </tr>
#     <tr>
#       <th id="T_bc5f3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bc5f3_row5_col0" class="data row5 col0" >0.0475</td>
#       <td id="T_bc5f3_row5_col1" class="data row5 col1" >0.0040</td>
#       <td id="T_bc5f3_row5_col2" class="data row5 col2" >0.0634</td>
#       <td id="T_bc5f3_row5_col3" class="data row5 col3" >0.8252</td>
#       <td id="T_bc5f3_row5_col4" class="data row5 col4" >0.0417</td>
#       <td id="T_bc5f3_row5_col5" class="data row5 col5" >0.1034</td>
#     </tr>
#     <tr>
#       <th id="T_bc5f3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bc5f3_row6_col0" class="data row6 col0" >0.0471</td>
#       <td id="T_bc5f3_row6_col1" class="data row6 col1" >0.0040</td>
#       <td id="T_bc5f3_row6_col2" class="data row6 col2" >0.0629</td>
#       <td id="T_bc5f3_row6_col3" class="data row6 col3" >0.8245</td>
#       <td id="T_bc5f3_row6_col4" class="data row6 col4" >0.0411</td>
#       <td id="T_bc5f3_row6_col5" class="data row6 col5" >0.0977</td>
#     </tr>
#     <tr>
#       <th id="T_bc5f3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bc5f3_row7_col0" class="data row7 col0" >0.0475</td>
#       <td id="T_bc5f3_row7_col1" class="data row7 col1" >0.0040</td>
#       <td id="T_bc5f3_row7_col2" class="data row7 col2" >0.0634</td>
#       <td id="T_bc5f3_row7_col3" class="data row7 col3" >0.8249</td>
#       <td id="T_bc5f3_row7_col4" class="data row7 col4" >0.0417</td>
#       <td id="T_bc5f3_row7_col5" class="data row7 col5" >0.0990</td>
#     </tr>
#     <tr>
#       <th id="T_bc5f3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bc5f3_row8_col0" class="data row8 col0" >0.0470</td>
#       <td id="T_bc5f3_row8_col1" class="data row8 col1" >0.0039</td>
#       <td id="T_bc5f3_row8_col2" class="data row8 col2" >0.0627</td>
#       <td id="T_bc5f3_row8_col3" class="data row8 col3" >0.8283</td>
#       <td id="T_bc5f3_row8_col4" class="data row8 col4" >0.0411</td>
#       <td id="T_bc5f3_row8_col5" class="data row8 col5" >0.0970</td>
#     </tr>
#     <tr>
#       <th id="T_bc5f3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bc5f3_row9_col0" class="data row9 col0" >0.0470</td>
#       <td id="T_bc5f3_row9_col1" class="data row9 col1" >0.0039</td>
#       <td id="T_bc5f3_row9_col2" class="data row9 col2" >0.0624</td>
#       <td id="T_bc5f3_row9_col3" class="data row9 col3" >0.8288</td>
#       <td id="T_bc5f3_row9_col4" class="data row9 col4" >0.0407</td>
#       <td id="T_bc5f3_row9_col5" class="data row9 col5" >0.0960</td>
#     </tr>
#     <tr>
#       <th id="T_bc5f3_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_bc5f3_row10_col0" class="data row10 col0" >0.0473</td>
#       <td id="T_bc5f3_row10_col1" class="data row10 col1" >0.0040</td>
#       <td id="T_bc5f3_row10_col2" class="data row10 col2" >0.0632</td>
#       <td id="T_bc5f3_row10_col3" class="data row10 col3" >0.8266</td>
#       <td id="T_bc5f3_row10_col4" class="data row10 col4" >0.0414</td>
#       <td id="T_bc5f3_row10_col5" class="data row10 col5" >0.0993</td>
#     </tr>
#     <tr>
#       <th id="T_bc5f3_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_bc5f3_row11_col0" class="data row11 col0" >0.0002</td>
#       <td id="T_bc5f3_row11_col1" class="data row11 col1" >0.0001</td>
#       <td id="T_bc5f3_row11_col2" class="data row11 col2" >0.0004</td>
#       <td id="T_bc5f3_row11_col3" class="data row11 col3" >0.0032</td>
#       <td id="T_bc5f3_row11_col4" class="data row11 col4" >0.0004</td>
#       <td id="T_bc5f3_row11_col5" class="data row11 col5" >0.0028</td>
#     </tr>
#   </tbody>
# </table>

# %%
x=pd.DataFrame({'Feature': get_config('X_train').columns}).to_csv('../../D2GNets/result/feature.csv')

# %%
lgbm_res= pull()

# %%
lgbm_res.to_csv('../../D2GNets/result/LGBM10fold.csv')

# %%
final_lgbm = finalize_model(lgbm)
save_model(final_et_LNIC50,'../../D2GNets/models/LGBM/Final_lgbm_Model_25June2022')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True,
#                                        features_todrop=['TCGA_DESC', 'LN_IC50',
#                                                         'SAMPLE_ID',
#                                                         'DRUG_NAME'],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=['ACC', 'ALL', 'BLCA',
#                                                            'BRCA', 'CESC', 'CLL',
#                                                            'COREAD', 'DLBC',
#                                                            'ESCA', 'GBM', 'HNSC',
#                                                            'KIRC', 'LAML',
#                                                            'LCML', 'LGG', 'LIHC',
#                                                            'LUAD', 'LUSC', 'MB...
#                   ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0,
#                                       criterion='mse', max_depth=None,
#                                       max_features='auto', max_leaf_nodes=None,
#                                       max_samples=None,
#                                       min_impurity_decrease=0.0,
#                                       min_impurity_split=None,
#                                       min_samples_leaf=1, min_samples_split=2,
#                                       min_weight_fraction_leaf=0.0,
#                                       n_estimators=100, n_jobs=-1,
#                                       oob_score=False, random_state=6343,
#                                       verbose=0, warm_start=False)]],
#           verbose=False),
#  '/data/user/rsharma3/nbotw/Project-D2GNETs/models/LGBM/Final_lgbm_Model_25June2022.pkl')

# %% [markdown]
# # Drug Screening experiment with Test data

# %%
# Prediction
unseen_predict =predict_model(lgbm, data=test)

# %%
#saving the resutlt
unseen_predict.to_csv('../../D2GNets/result/unseen_predict.csv',index=False)

# %% [markdown]
# # Drug Repurposing Experiment

# %%
# Prediction 
GBM_Carmustine_pred = predict_model(final_lgbm, data=GBM_test_Carmustine)
GBM_Temozolomide_pred = predict_model(final_lgbm, data=GBM_test_Temozolomide)

# %%
# Saving the Results of drug Repurposing
GBM_Carmustine_pred.to_csv('../../D2GNets/result/GBM_Carmustine_pred.csv',index=False)
GBM_Temozolomide_pred.to_csv('../../D2GNets/result/GBM_Temozolomide_pred.csv',index=False)
